# %% [markdown]
# # <center>Прогноз просрочки кредита заемщиком</center>

# %% [markdown]
# ### Описание набора данных
#
# Данные представляют собой исторические данные по `250k` заемщикам. Задача является бинарной классификацией. **Цель** - предсказать будет ли тот или иной заемщик испытывать финансовые трудности в ближайшие 2 года, т.е. будет ли просрочка по займу. Выборка разделена на тренировочную и тестовую ( `150k` в тренировочной части, `100k` в тестовой).
#
# Данная решаемая задача будет ценна как кредиторам, так и заемщикам для оценки способности вернуть долг вовремя.
#
# ### Описание признаков
#
# * 1 - __SeriousDlqin2yrs__ - будет ли просрочка более 90 дней в ближайшие 2 года (целевая метка) (Да/Нет)
# * 2 - __RevolvingUtilizationOfUnsecuredLines__ - общий баланс по кредитным картам и кредитным линиям, за исключением задолженностей по недвижимости задолженности по взносам, деленные на сумму кредитных лимитов (проценты)
# * 3 - __age__ - Возраст заемщика (в годах)
# * 4 - __NumberOfTime30-59DaysPastDueNotWorse__ - количество просрочек в 30-59 дней (Целое)
# * 5 - __DebtRatio__ - коэффициент задолженности, т.е. сумма ежемесячных платежей по долгам, алиментов и расходов на проживание, деленная на месячный доналоговый доход (проценты)
# * 6 - __Monthly Income__ - месячный доход (число с плавающей точкой)
# * 7 - __NumberOfOpenCreditLinesAndLoans__ - количество открытых кредитов и кредитных линий (Целое)
# * 8 - __NumberOfTimes90DaysLate__ - количество просрочек более 90 дней (Целое)
# * 9 - __NumberRealEstateLoansOrLines__ - количество ипотечных кредитов и кредитов на недвижимость, включая кредитные линии домашнего капитала (Целое)
# * 10 - __NumberOfTime60-89DaysPastDueNotWorse__ - количество просрочек в 60-89 дней за последние 2 года (Целое)
# * 11 - __NumberOfDependents__ - количество иждивенцев в семье (исключая самих заемщиков) (Целое)

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm_notebook as tqdm

# %matplotlib inline
from matplotlib import pyplot as plt
plt.style.use(['seaborn-darkgrid'])
plt.rcParams['font.family'] = 'DejaVu Sans'

from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import validation_curve, learning_curve
RANDOM_STATE = 17

cm = sns.light_palette("pink", as_cmap=True)
def print_frame(frame, columnsNames=None, indexNames=None):
    if "Series" in str(type(frame)): frame= frame.to_frame()
    if columnsNames: frame.columns = columnsNames
    if indexNames: frame.index = indexNames
    return frame.style.set_properties(**{'background-color': '#FFE7E7'})\
           .background_gradient(cmap=cm)

# %%
def make_submission(predictions, fname):
    out = pd.DataFrame(data=predictions, columns=['Probability'])
    out.index += 1
    out.to_csv(fname, index_label='id')

# %%
df = pd.read_csv('data/credit/cs-training.csv', index_col=0)
feature_names = df.columns[1:]
df.head()
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 1                 1                              0.766127   45
# 2                 0                              0.957151   40
# 3                 0                              0.658180   38
# 4                 0                              0.233810   30
# 5                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 1                                     2   0.802982         9120.0
# 2                                     0   0.121876         2600.0
# 3                                     1   0.085113         3042.0
# 4                                     0   0.036050         3300.0
# 5                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 1                               13                        0
# 2                                4                        0
# 3                                2                        1
# 4                                5                        0
# 5                                7                        0
#
#    NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 1                             6                                     0
# 2                             0                                     0
# 3                             0                                     0
# 4                             0                                     0
# 5                             1                                     0
#
#    NumberOfDependents
# 1                 2.0
# 2                 1.0
# 3                 0.0
# 4                 0.0
# 5                 0.0

# %%
print("Размер тренеровочного сэта:", df.shape)
df.describe(include = "all").T.style.background_gradient(cmap=cm)
# Out:
# Размер тренеровочного сэта: (150000, 11)
# <style  type="text/css" >
#     #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row0_col0 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row0_col1 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row0_col2 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row0_col3 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row0_col4 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row0_col5 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row0_col6 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row0_col7 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row1_col0 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row1_col1 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row1_col2 {
#             background-color:  #ffe5e9;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row1_col3 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row1_col4 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row1_col5 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row1_col6 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row1_col7 {
#             background-color:  #ffe5e9;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row2_col0 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row2_col1 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row2_col2 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row2_col3 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row2_col4 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row2_col5 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row2_col6 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row2_col7 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row3_col0 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row3_col1 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row3_col2 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row3_col3 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row3_col4 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row3_col5 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row3_col6 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row3_col7 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row4_col0 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row4_col1 {
#             background-color:  #ffe4e8;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row4_col2 {
#             background-color:  #ffe0e6;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row4_col3 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row4_col4 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row4_col5 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row4_col6 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row4_col7 {
#             background-color:  #ffe1e7;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row5_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row5_col1 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row5_col2 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row5_col3 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row5_col4 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row5_col5 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row5_col6 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row5_col7 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row6_col0 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row6_col1 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row6_col2 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row6_col3 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row6_col4 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row6_col5 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row6_col6 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row6_col7 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row7_col0 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row7_col1 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row7_col2 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_7f670aa5_ea0b_11ea_afae_bce92f6864a7row7_col3 {
#             background-color:  #ffe5ea;
#             color:  #000000;

# %%
df.nunique()
# Out:
# SeriousDlqin2yrs                             2
# RevolvingUtilizationOfUnsecuredLines    125728
# age                                         86
# NumberOfTime30-59DaysPastDueNotWorse        16
# DebtRatio                               114194
# MonthlyIncome                            13594
# NumberOfOpenCreditLinesAndLoans             58
# NumberOfTimes90DaysLate                     19
# NumberRealEstateLoansOrLines                28
# NumberOfTime60-89DaysPastDueNotWorse        13
# NumberOfDependents                          13
# dtype: int64

# %% [markdown]
# Проверим на наличие NaN

# %%
print("|NumberOfDependents - количество иждивенцев в семье (исключая самих заемщиков)\n"
      "|Monthly Income - месячный доход\n"
      "|MonthlyIncome & NumberOfDependents = ",
    (df['MonthlyIncome'].isnull() & df['NumberOfDependents'].isnull()).sum())

isnull_info  = df.isnull().sum()
print_frame(isnull_info, columnsNames=['Null Count'])
# Out:
# |NumberOfDependents - количество иждивенцев в семье (исключая самих заемщиков)
# |Monthly Income - месячный доход
# |MonthlyIncome & NumberOfDependents =  3924
# <style  type="text/css" >
#     #T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row0_col0 {
#             background-color:  #FFE7E7;
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row1_col0 {
#             background-color:  #FFE7E7;
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row2_col0 {
#             background-color:  #FFE7E7;
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row3_col0 {
#             background-color:  #FFE7E7;
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row4_col0 {
#             background-color:  #FFE7E7;
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row5_col0 {
#             background-color:  #FFE7E7;
#             background-color:  #ffc0cb;
#             color:  #000000;
#         }    #T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row6_col0 {
#             background-color:  #FFE7E7;
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row7_col0 {
#             background-color:  #FFE7E7;
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row8_col0 {
#             background-color:  #FFE7E7;
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row9_col0 {
#             background-color:  #FFE7E7;
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }    #T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row10_col0 {
#             background-color:  #FFE7E7;
#             background-color:  #ffe1e6;
#             color:  #000000;
#         }</style><table id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Null Count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7level0_row0" class="row_heading level0 row0" >SeriousDlqin2yrs</th>
#                         <td id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row0_col0" class="data row0 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7level0_row1" class="row_heading level0 row1" >RevolvingUtilizationOfUnsecuredLines</th>
#                         <td id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row1_col0" class="data row1 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7level0_row2" class="row_heading level0 row2" >age</th>
#                         <td id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row2_col0" class="data row2 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7level0_row3" class="row_heading level0 row3" >NumberOfTime30-59DaysPastDueNotWorse</th>
#                         <td id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row3_col0" class="data row3 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7level0_row4" class="row_heading level0 row4" >DebtRatio</th>
#                         <td id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row4_col0" class="data row4 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7level0_row5" class="row_heading level0 row5" >MonthlyIncome</th>
#                         <td id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row5_col0" class="data row5 col0" >29731</td>
#             </tr>
#             <tr>
#                         <th id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7level0_row6" class="row_heading level0 row6" >NumberOfOpenCreditLinesAndLoans</th>
#                         <td id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row6_col0" class="data row6 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7level0_row7" class="row_heading level0 row7" >NumberOfTimes90DaysLate</th>
#                         <td id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row7_col0" class="data row7 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7level0_row8" class="row_heading level0 row8" >NumberRealEstateLoansOrLines</th>
#                         <td id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row8_col0" class="data row8 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7level0_row9" class="row_heading level0 row9" >NumberOfTime60-89DaysPastDueNotWorse</th>
#                         <td id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row9_col0" class="data row9 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7level0_row10" class="row_heading level0 row10" >NumberOfDependents</th>
#                         <td id="T_812ea01a_ea0b_11ea_a25a_bce92f6864a7row10_col0" class="data row10 col0" >3924</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# По всей видимости, часть заемщиков отказалась разглашать информацию о своих доходах а также о членах семьи.
# Для месячного дохода заменим NaN на среднее значение по выборке, для количества иждивенцев - на 0

# %%
df['MonthlyIncome'].fillna(df['MonthlyIncome'].mean(), inplace=True)
df['NumberOfDependents'].fillna(0, inplace=True)

# %%
credit_info = df['SeriousDlqin2yrs'].value_counts()
print_frame(credit_info, indexNames= ["Вернул", "Просрочил"])
# Out:
# <style  type="text/css" >
#     #T_a759c294_ea0b_11ea_8bc4_bce92f6864a7row0_col0 {
#             background-color:  #FFE7E7;
#             background-color:  #ffc0cb;
#             color:  #000000;
#         }    #T_a759c294_ea0b_11ea_8bc4_bce92f6864a7row1_col0 {
#             background-color:  #FFE7E7;
#             background-color:  #ffe5ea;
#             color:  #000000;
#         }</style><table id="T_a759c294_ea0b_11ea_8bc4_bce92f6864a7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SeriousDlqin2yrs</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a759c294_ea0b_11ea_8bc4_bce92f6864a7level0_row0" class="row_heading level0 row0" >Вернул</th>
#                         <td id="T_a759c294_ea0b_11ea_8bc4_bce92f6864a7row0_col0" class="data row0 col0" >139974</td>
#             </tr>
#             <tr>
#                         <th id="T_a759c294_ea0b_11ea_8bc4_bce92f6864a7level0_row1" class="row_heading level0 row1" >Просрочил</th>
#                         <td id="T_a759c294_ea0b_11ea_8bc4_bce92f6864a7row1_col0" class="data row1 col0" >10026</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Т.о., классы не равны по размеру, количество заемщиков, сильно просрочивших возврат кредита значительно меньше, чем вовремя вернувших его.

# %% [markdown]
# ### Визуализация данныx

# %%
sns.pairplot(df, hue='SeriousDlqin2yrs', size=4.5);

# %%
fig=plt.gcf()
fig.set_size_inches(12,10)
fig=sns.heatmap(df.corr(), annot=True, cmap='inferno',
                linewidths=1, linecolor='y', square=True,
                mask=False, vmin=-1, vmax=1, )

# %% [markdown]
# ### <center>Закономерности:</center>
#
# * __age__ Возраст заемщиков вне зависимости от значения целевой метки имеет распрделение, близкое к нормальному.
# * __RealEstateLoansOrLines__ __OpenCreditLinesAndLoans__ Количество открытых кредитов коррелирует с количеством кредитов на недвижимость, что можно объяснить общей активностью заемщика.
# * Целевая переменная зависит от количества предыдущих просрочек, чем больше по длительности была каждая просрочка, тем больше вероятность будущей.

# %% [markdown]
# __Подготовка данных__

# %%
X_train = df.drop(columns=['SeriousDlqin2yrs'])
y_train = df['SeriousDlqin2yrs']

df_test = pd.read_csv('data/credit/cs-test.csv', index_col=0)
df_test['MonthlyIncome'].fillna(df_test['MonthlyIncome'].mean(), inplace=True)
df_test['NumberOfDependents'].fillna(0, inplace=True)

X_test = df_test.drop(columns=['SeriousDlqin2yrs'])

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# __Выбор метрики__

# %% [markdown]
# В качестве метрики используется ROC-AUC score. Данная метрика подходит для данной задачи, так как мы хотим определять тех заемщиков, которые сильно задержат выплату кредита, но при этом выдавать кредиты хорошим клиентам. Также эта метрика хорошо работает со случаем несбалансированных классов (как в нашем случае).
#
# Для валидации был выбран метод Stratified KFold (т.к. выборка не сбалансирована) на 5 фолдов.

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# Обучим 2 классификатора - логистическую регрессию и случайный лес.
# Сначала посмотрим на результаты при дефолтных параметрах.

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)
logit = LogisticRegression(random_state=RANDOM_STATE, solver='lbfgs', verbose=0)
forest = RandomForestClassifier(n_estimators=50, n_jobs=-1, random_state=RANDOM_STATE, verbose=0)

scores = []

classifiers = [logit, forest]
for c in tqdm(classifiers, total=len(classifiers)):
    scores.append(cross_val_score(c, X_train_scaled, y_train, scoring='roc_auc', cv=kfold,n_jobs=-1, verbose=1))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    7.5s finished

# %%
print("{:.2%} - Logistic Regression \n{:.2%} - Random Forest Classifier"\
      .format(*np.mean(scores, axis=1)))
# Out:
# 69.83% - Logistic Regression
# 83.14% - Random Forest Classifier

# %% [markdown]
# __Кросс-валидация и подбор параметров__
#
# Произведем подбор параметров. Для логистической регрессии подберем коэффициент регуляризции, для случайного леса - максимальную глубину и максимальное кол-во признаков.

# %%
# %%time
logit_params = {'C': np.logspace(0, 2, 7)}
forest_params = {'min_samples_leaf':[1, 3, 5, 7],
                 'max_depth': [None] + list(range(5, 15))}

logit_grid = GridSearchCV(logit, logit_params, scoring='roc_auc', n_jobs=-1,cv=kfold, verbose=1)
forest_grid = GridSearchCV(forest, forest_params, scoring='roc_auc', n_jobs=-1,cv=kfold, verbose=1)

scores_grid = []

classifiers_grid = [logit_grid, forest_grid]
for c in tqdm(classifiers_grid, total=len(classifiers_grid)):
    c.fit(X_train_scaled, y_train)
    scores_grid.append(c.best_score_)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    3.0s finished
# Fitting 5 folds for each of 44 candidates, totalling 220 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 220 out of 220 | elapsed:  3.5min finished
# Wall time: 3min 37s

# %%
print("{:.2%} - Logistic Regression after Grid Search CV \n{:.2%} - Random Forest Classifier after Grid Search CV"\
      .format(*scores_grid))
# Out:
# 69.83% - Logistic Regression after Grid Search CV
# 86.43% - Random Forest Classifier after Grid Search CV

# %% [markdown]
# Лучший результат дал случайный лес. Выведем подобранные параметры.

# %%
forest_grid.best_params_
# Out:
# {'max_depth': 11, 'min_samples_leaf': 7}

# %%
predictions = forest_grid.predict_proba(X_test_scaled)[:, 1]
make_submission(predictions, 'sub1.csv')

# %% [markdown]
# Данная модель дает результат 0.860890 на public leaderboard и 0.864706 на private.

# %% [markdown]
# __Создание новых признаков__

# %% [markdown]
# Разделим заемщиков на 2 группы по возрасту (до и старше 18). Также создадим признак если ли иждевенцы у заемщика, количество возобновляемых кредитный линий (разность между общим кол-вом линий и заемов и количеством кредитов на недвижимость) и отношение кол-ва возобновляемых линий к кол-ву кредитов на недвижимость - данный признак показывает какой тип кредитов чаще берет заемщик.

# %%
df_features_train = pd.DataFrame(index=df.index)
df_features_train['age<18'] = df['age'].apply(lambda x: 1 if x < 18 else 0)

df_features_train['AgeDep'] = df['age'] / df['NumberOfDependents']
df_features_train['AgeDep'][df['NumberOfDependents'] == 0] = 0

df_features_train['NoDependents'] = (df['NumberOfDependents'] == 0)
df_features_train['RevolvLines'] = df['NumberOfOpenCreditLinesAndLoans'].values - df['NumberRealEstateLoansOrLines'].values
df_features_train['Rev2Estate'] = df_features_train['RevolvLines'] / (1 + df['NumberRealEstateLoansOrLines']) 

df_features_test = pd.DataFrame(index = df_test.index)
df_features_test['age<18'] = df_test['age'].apply(lambda x: 1 if x < 18 else 0)

df_features_test['AgeDep'] = df_test['age'] / df_test['NumberOfDependents']
df_features_test['AgeDep'][df_test['NumberOfDependents'] == 0] = 0

df_features_test['NoDependents'] = (df_test['NumberOfDependents'] == 0)
df_features_test['RevolvLines'] = df_test['NumberOfOpenCreditLinesAndLoans'].values - df_test['NumberRealEstateLoansOrLines'].values
df_features_test['Rev2Estate'] = df_features_test['RevolvLines'] / (1 + df_test['NumberRealEstateLoansOrLines'])

# %%
X_train_feat = pd.concat([X_train, df_features_train], axis=1)
X_test_feat = pd.concat([X_test, df_features_test], axis=1)

scaler = StandardScaler()
X_train_feat_scaled = scaler.fit_transform(X_train_feat)
X_test_feat_scaled = scaler.transform(X_test_feat)

# %%
# %%time
forest_best = forest_grid.best_estimator_
result_feat = cross_val_score(forest_best, X_train_feat_scaled, y_train, cv=kfold, scoring='roc_auc',n_jobs=-1)
# Out:
# Wall time: 5.42 s

# %%
print("{:.3%} -  Forest Grid".format(np.mean(result_feat)))
# Out:
# 86.376% -  Forest Grid

# %%
forest_best.fit(X_train_feat_scaled, y_train)
# Out:
# RandomForestClassifier(max_depth=11, min_samples_leaf=7, n_estimators=50,
#                        n_jobs=-1, random_state=17)

# %%
predictions = forest_best.predict_proba(X_test_feat_scaled)[:, 1]

# %%
make_submission(predictions, 'sub2.csv')

# %% [markdown]
# После создания новых признаков улучшился результат на private:
#     0.860624 - на public;
#     0.866692 - на private.

# %% [markdown]
# __Кривые валидации и обучения__

# %%
def plot_with_std(x, data, **kwargs):
        mu, std = data.mean(1), data.std(1)
        lines = plt.plot(x, mu, '-', **kwargs)
        plt.fill_between(x, mu - std, mu + std, edgecolor='none',
                         facecolor=lines[0].get_color(), alpha=0.2)
        
def plot_learning_curve(clf, X, y, scoring, cv=5, random_state=17):
 
    train_sizes = np.linspace(0.05, 1, 20)
    n_train, val_train, val_test = learning_curve(clf,
                                                  X, y, train_sizes=train_sizes, cv=cv,
                                                  scoring=scoring, random_state=random_state, n_jobs=-1)
    plot_with_std(n_train, val_train, label='training scores', c='green')
    plot_with_std(n_train, val_test, label='validation scores', c='red')
    plt.xlabel('Training Set Size'); plt.ylabel(scoring)
    plt.legend()

def plot_validation_curve(clf, X, y, cv_param_name, 
                          cv_param_values, scoring, cv=5, random_state=17):

    val_train, val_test = validation_curve(clf, X, y, cv_param_name,
                                           cv_param_values, cv=cv,
                                                  scoring=scoring, n_jobs=-1)
    plot_with_std(cv_param_values, val_train, 
                  label='training scores', c='green')
    plot_with_std(cv_param_values, val_test, 
                  label='validation scores', c='red')
    plt.xlabel(cv_param_name); plt.ylabel(scoring)
    plt.legend()

# %%
plot_validation_curve(forest_best, X_train_feat_scaled, y_train, 'min_samples_leaf', [1, 3, 5, 7], scoring='roc_auc', cv=kfold, random_state=RANDOM_STATE);

# %%
plot_learning_curve(forest_best, X_train_feat_scaled, y_train, scoring='roc_auc', cv=kfold)

# %% [markdown]
# __Оценка модели с описанием выбранной метрики__
#
# Построена модель предсказания, предсказывающая просрочит ли заемщик выплату кредита на более чем 90 дней. В качестве целевой метрики была выбрана ROC-AUC score, позволяющая хорошо оценивать предсказания при сильно несбалансированной выборке. Построенная модель. Результат работы модели  $ROC-AUC \approx 0.86$.
#
# Построены кривые обучения и валидационные кривые. Согласно ним, увеличение числа примеров больше 1000000 не дает существенного прироста в качестве.

# %% [markdown]
# __Общие выводы__
#
# По результатам проведенного анализа, можно увидеть, что есть определенные зависимости и признаки просрочки кредита.
# Наблюдаются определенные закономерности - месячный доход, возраст заемщика.
#
# Имеет влияние количество и длительность предыдущих просрочек - с ростом их числа, заемщик становиться менее привлекательным в связи с высокой вероятностью новой просрочки.
#
# Также влияет и количество иждевенцев у заемщика - клиент с семьей реже не выплачивает кредит вовремя.
#
# В дальнейшем, можно добавить новые признаки (логарифмическая зависимость и т.д.)
# Также можно заменить случайный лес на градиентый бустинг.
