# %% [markdown]
# # <center> Прямые звонки из банка </center>

# %% [markdown]
# В ходе проекта решается задача прогнозирования положительного отклика (срочный вклад) на прямые звонки из банка.
#
# По-сути, задача является задачей банковского скоринга, т.е. по характеристикам клиента (потенциального клиента), предсказывается его поведение (невозврат кредита, желание открыть вклад и т.д.). В департаментах рисков банков существуеют строгие требования к интерпретируемости модели, поэтому я хочу рассмотреть 2 решения: "банковское" и свободное. Задача обзвона клиентов не является задачей определения риска дефолта, поэтому на неё не накладывается условие интерпретируемости, однако задача схожая, и думаю интересно на ее примере показать решение с ограничением (интерпретируемость).

# %% [markdown]
# Датасет содержит 41188 объектов, для кадого из которых задан 21 признак, в том числе 1 целевой.
#
# Рассмотрим по порядку все имеющиеся признаки:
# 1) **age** - возраст потенциального клиента в годах
# 2) **job** - профессия (Возможны следующие значения: *admin., blue-collar, entrepreneur, housemaid, management, retired, self-employed, services, student, technician, unemployed, unknown*)
# 3) **marital** - семейное положение (Значения: *divorced, married, single, unknown*)
# 4) **education** - образование (Значения: *basic.4y, basic.6y, basic.9y, high.school, illiterate, professional.course, university.degree, unknown*)
# 5) **default** - есть ли дефолт по кредиту (Значения: *no, yes, unknown*)
# 6) **housing** - есть ли кредит на жильё (Значения: *no, yes, unknown*)
# 7) **loan** - есть ли потребительский кредит (Значения: *no, yes, unknown*)
# 8) **contact** - способ связи c потенциальным клиентом (Значения: *cellular, telephone*)
# 9) **month** - номер месяца, когда был крайний контакт с клиентом (Значения: *jan, feb, mar, ... , nov, dec*)
# 10) **day_of_week** - день недели, когда был крайний контакт с клиентом (Значения: *mon, tue, wed, thu, fri*)
# 11) **duration** - продолжительность крайнего звонка клиенту (Имеется ввиду, звонок, результат которого мы прогнозируем, в секундах)
# 12) **campaign** - количество контактов с данным клиентом в течение текущей компании
# 13) **pdays** - количество дней, прошедшее с предыдущего контакта (999 для новых клиентов)
# 14) **previous** - количество контактов с данным клиенто до текущей компании
# 15) **poutcome** - результат предыдущей маркетинговой компании (Значения: *failure, nonexistent, success*)
# 16) **emp.var.rate** - коэффициент изменения занятости - квартальный показатель
# 17) **cons.price.idx** - индекс потребительских цен - месячный показатель
# 18) **cons.conf.idx** - индекс доверия потребителей - ежемесячный показатель
# 19) **euribor3m** - euribor 3-месячный курс - дневной индикатор
# 20) **nr.employed** - количество сотрудников - квартальный показатель
#
# Целевой признак:
#
# 21) **y** - подписал ли клиент срочный вклад (Значения: *yes, no*)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
cm = sns.light_palette("pink", as_cmap=True)
try: from sprint import sprint
except: sprint = lambda df, **noUse: df.style.background_gradient(cmap=cm)

# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib.style as style
plt.style.use('fivethirtyeight')
plt.rcParams['font.family'] = 'DejaVu Sans'

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import train_test_split, StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from sklearn import preprocessing
from sklearn.model_selection import validation_curve
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
import time
import warnings
warnings.filterwarnings('ignore')

# %%
raw_data = pd.read_csv('data/bank-additional-full.csv', header = 0, sep = ';')
df = raw_data.copy()
pd.set_option('display.max_columns', 100)

# %%
print("SHAPE =", df.shape)
sprint(df.head(10))
# Out:
# SHAPE = (41188, 21)
# <style  type="text/css" >
#     #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307 tr:hover td {
#           background-color: #ffedf0;
#     }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307 tbody tr:hover th {
#           background: white;
#     }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307 th:hover, td:hover {
#           background: #ffe2e7 !important;
#     }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307 th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: #2e2224;
#           background: #fff3f5;
#     }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307 td {
#           font-size: 11px;
#     }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row0_col0 {
#             background-color:  #ffc3ce;
#             color:  #000000;
#             : ;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row0_col10 {
#             background-color:  #ffced6;
#             color:  #000000;
#             : ;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row0_col11 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row0_col12 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row0_col13 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row0_col15 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row0_col16 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row0_col17 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row0_col18 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row0_col19 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row1_col0 {
#             background-color:  #ffc2cd;
#             color:  #000000;
#             : ;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row1_col10 {
#             background-color:  #ffdae1;
#             color:  #000000;
#             : ;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row1_col11 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row1_col12 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row1_col13 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row1_col15 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row1_col16 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row1_col17 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row1_col18 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row1_col19 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row2_col0 {
#             background-color:  #ffd8de;
#             color:  #000000;
#             : ;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row2_col10 {
#             background-color:  #ffd2d9;
#             color:  #000000;
#             : ;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row2_col11 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row2_col12 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row2_col13 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row2_col15 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row2_col16 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row2_col17 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row2_col18 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row2_col19 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row3_col0 {
#             background-color:  #ffd4dc;
#             color:  #000000;
#             : ;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row3_col10 {
#             background-color:  #ffdae0;
#             color:  #000000;
#             : ;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row3_col11 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row3_col12 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row3_col13 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row3_col15 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row3_col16 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row3_col17 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row3_col18 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row3_col19 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row4_col0 {
#             background-color:  #ffc3ce;
#             color:  #000000;
#             : ;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row4_col10 {
#             background-color:  #ffc8d2;
#             color:  #000000;
#             : ;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row4_col11 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15e39f57_ec7b_11ea_9b9b_3c58c2d24307row4_col12 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-c

# %% [markdown]
# Проверим, есть ли в данных отсутствующие значения:

# %%
sprint(df.isnull().sum(), columnsNames=["Null Count"])
# Out:
# <style  type="text/css" >
#     #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307 tr:hover td {
#           background-color: #ffedf0;
#     }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307 tbody tr:hover th {
#           background: white;
#     }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307 th:hover, td:hover {
#           background: #ffe2e7 !important;
#     }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307 th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: #2e2224;
#           background: #fff3f5;
#     }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307 td {
#           font-size: 11px;
#     }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row0_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row1_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row2_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row3_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row4_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row5_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row6_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row7_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row8_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row9_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row10_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row11_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row12_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row13_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row14_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row15_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row16_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row17_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row18_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row19_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row20_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }</style><table id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Null Count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307level0_row0" class="row_heading level0 row0" >age</th>
#                         <td id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row0_col0" class="data row0 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307level0_row1" class="row_heading level0 row1" >job</th>
#                         <td id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row1_col0" class="data row1 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307level0_row2" class="row_heading level0 row2" >marital</th>
#                         <td id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row2_col0" class="data row2 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307level0_row3" class="row_heading level0 row3" >education</th>
#                         <td id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row3_col0" class="data row3 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307level0_row4" class="row_heading level0 row4" >default</th>
#                         <td id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row4_col0" class="data row4 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307level0_row5" class="row_heading level0 row5" >housing</th>
#                         <td id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row5_col0" class="data row5 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307level0_row6" class="row_heading level0 row6" >loan</th>
#                         <td id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row6_col0" class="data row6 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307level0_row7" class="row_heading level0 row7" >contact</th>
#                         <td id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row7_col0" class="data row7 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307level0_row8" class="row_heading level0 row8" >month</th>
#                         <td id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row8_col0" class="data row8 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307level0_row9" class="row_heading level0 row9" >day_of_week</th>
#                         <td id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row9_col0" class="data row9 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307level0_row10" class="row_heading level0 row10" >duration</th>
#                         <td id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row10_col0" class="data row10 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307level0_row11" class="row_heading level0 row11" >campaign</th>
#                         <td id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row11_col0" class="data row11 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307level0_row12" class="row_heading level0 row12" >pdays</th>
#                         <td id="T_15eb61b7_ec7b_11ea_8ea4_3c58c2d24307row12_co

# %% [markdown]
# Как видим, данные полные, пропусков нет, поэтому нет необходимости заполнять пропуски.
# Далее проверим данные на выбросы. Для начала сравним минимальное и максимальное значение со средним (для численных признаков):

# %%
sprint(df.describe(include = ['int64', 'float64']).drop('count'))
# Out:
# <style  type="text/css" >
#     #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307 tr:hover td {
#           background-color: #ffedf0;
#     }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307 tbody tr:hover th {
#           background: white;
#     }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307 th:hover, td:hover {
#           background: #ffe2e7 !important;
#     }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307 th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: #2e2224;
#           background: #fff3f5;
#     }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307 td {
#           font-size: 11px;
#     }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row0_col0 {
#             background-color:  #ffd9e0;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row0_col1 {
#             background-color:  #ffe4e8;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row0_col2 {
#             background-color:  #ffe4e9;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row0_col3 {
#             background-color:  #ffc1cc;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row0_col4 {
#             background-color:  #ffe5e9;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row0_col5 {
#             background-color:  #ffcbd4;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row0_col6 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row0_col7 {
#             background-color:  #ffdfe4;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row0_col8 {
#             background-color:  #ffccd5;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row0_col9 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row1_col0 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row1_col1 {
#             background-color:  #ffe4e8;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row1_col2 {
#             background-color:  #ffe4e9;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row1_col3 {
#             background-color:  #ffdfe4;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row1_col4 {
#             background-color:  #ffe3e8;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row1_col5 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row1_col6 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row1_col7 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row1_col8 {
#             background-color:  #ffdce2;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row1_col9 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row2_col0 {
#             background-color:  #ffe3e8;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row2_col1 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row2_col2 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row2_col3 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row2_col4 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row2_col5 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row2_col6 {
#             background-color:  #ffc1cc;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row2_col7 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row2_col8 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row2_col9 {
#             background-color:  #ffc2cd;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row3_col0 {
#             background-color:  #ffdce2;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row3_col1 {
#             background-color:  #ffe5e9;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row3_col2 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row3_col3 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row3_col4 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row3_col5 {
#             background-color:  #ffd9e0;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row3_col6 {
#             background-color:  #ffc1cb;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row3_col7 {
#             background-color:  #ffe0e5;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row3_col8 {
#             background-color:  #ffdfe5;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row3_col9 {
#             background-color:  #ffc1cc;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row4_col0 {
#             background-color:  #ffdae0;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row4_col1 {
#             background-color:  #ffe4e9;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row4_col2 {
#             background-color:  #ffe5e9;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row4_col3 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#             background-color:  #FFBCCF;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row4_col4 {
#             background-color:  #ffe5ea;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row4_col5 {
#             background-color:  #ffc4ce;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row4_col6 {
#             background-color:  #ffc0cb;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row4_col7 {
#             background-color:  #ffdfe5;
#             color:  #000000;
#             : ;
#         }    #T_15f64209_ec7b_11ea_9bc3_3c58c2d24307row4_col8 {
#             background-color:  #ffc1cc;
#             color:  #000000;
#             :

# %% [markdown]
# В целом, по этим данным, нельзя сказать, что в данных есть откровенные выбросы. Однанако, такой проверки недостаточно,
# желательно ещё посмотреть графики зависимости целевого признака от каждого из признаков, но это мы сделаем чуть позже,
# когда будем визуализировать признаки и зависимости.
#
# Далее посмотрим на распределения числовых признаков. Для этого воспользуемся библиотекой Seaborn.

# %%
categorial = []
numerical = []
for feature in df.columns:
    if df[feature].dtype == object:
        categorial.append(feature)
    else:
        numerical.append(feature)

df[numerical].hist(figsize=(20,14), bins=70, color='#FD8185');

# %% [markdown]
# Из гистограмм мы видим, что **для каждого численного признака есть одно или несколько доминирующих отрезков значений**,
# из-за чего мы получили ярко выраженные пики.
#
# Далее осмотрим на категориальные признаки:

# %%
df.describe(include = ['object'])
# Out:
#            job  marital          education default housing   loan   contact  \
# count    41188    41188              41188   41188   41188  41188     41188
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq     10422    24928              12168   32588   21576  33950     26144
#
#         month day_of_week     poutcome      y
# count   41188       41188        41188  41188
# unique     10           5            3      2
# top       may         thu  nonexistent     no
# freq    13769        8623        35563  36548

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.titlesize'] = 24
plt.rcParams['font.size'] = 20

fig, axes = plt.subplots(ncols=4, nrows = 3, figsize=(24, 18))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.4)

for i in range(len(categorial)):
    df[categorial[i]].value_counts(normalize=True).plot(
        kind='bar', label=categorial[i], ax=axes[i//4, i%4], color='#FD8185')
    axes[i//4, i%4].set_title(categorial[i])
plt.tight_layout()

# %% [markdown]
# Как видим, для многих признаков, какая-то из групп привалирует, например, в датасете более половины клиентов женаты/замужем.
#
# Помимо этого мы видим, что целевой признак несбалансирован. **Количество положительных исходов существенно ниже, чем отрицательных**, что вполне естественно для телефонного маркетинга. Вследствие этого, возникает проблема с тем, что многие методы чувствительны к несбалансированности признаков. Данную проблему мы дальше постораемся решить.

# %% [markdown]
# Посмотрим на матрицу корреляции (для числовых признаков):

# %%
# Ищем коррелирующие признаки
plt.rcParams['font.size'] = 12

fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.heatmap(df.corr().round(2), annot=True, cmap='spring',
                linewidths=1, linecolor='y', square=True,
                mask=False, vmin=-1, vmax=1, 
                cbar_kws={"orientation": "vertical"})

# %% [markdown]
# Визуализируем матрицу корреляции:

# %% [markdown]
# Как видно из таблицы и тепловой карты **euribor3m и nr.employed сильно коррелируют с emp.var.rate**, впоследствии, на этапе отбора признаков мы их удалим, когда будем отбирать признаки.

# %% [markdown]
# Целевой признак показывает положительный ли результат телефонного звонка в ходе маркетинговой компании.
# Обозначим положительный исход как 1, отрицательный как 0:

# %%
df['y'] = df['y'].map({'yes': 1, 'no': 0})

# %% [markdown]
# Посмотрим на визуализированные зависимости вещественных признаков от целевого признака:

# %%
plt.rcParams['font.size'] = 20
fig, axes = plt.subplots(ncols=4, nrows = 3, figsize=(24, 18))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.4)

for i in range(len(numerical)):
    df.plot(x=numerical[i], y = 'y', label=numerical[i], ax=axes[i//4, i%4], kind='scatter', color='#FD8185')
    axes[i//4, i%4].set_title(numerical[i])
plt.tight_layout()

# %% [markdown]
# Как видим, есть точки, которые можно интерпретировать как выбросы есть, однако, я бы не спешил их удалять, т.к. мне они не кажутся выбросами в чистом виде. Т.е. это врядли ошибки и выбросы слишком сильные, пока я их оставлю. К тому же, для начала я намерен использовать RandomForest, а деревья, как известно, устойчивы к выбросам.

# %% [markdown]
# Категориальные признаки необходимо сделать числовыми, для этого я использую LabelEncoder. OneHotEncoder не использую, т.к. для категориальных признаков в дальнейшем буду считать WOE (см. дальше), поэтому нам неважно как занумеровывать категории.

# %%
categorial.remove('y')
df[categorial] = df[categorial].apply(LabelEncoder().fit_transform)

# %%
fig, axes = plt.subplots(ncols=4, nrows = 3, figsize=(24, 18))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.4)

for i in range(len(categorial)):
    sns.countplot(x=categorial[i], hue='y', data=df, ax=axes[i//4, i%4])
    axes[i//4, i%4].set_title(categorial[i])

plt.tight_layout()

# %% [markdown]
# Из данных графиков видно некоторые зависимости, но лучше посмотреть в несколько другом виде.
# Визуализируем **долю положительных откликов** по группам:

# %%
fig, axes = plt.subplots(ncols=4, nrows = 3, figsize=(24, 18))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.4)

for i in range(len(categorial)):
    df.groupby(categorial[i])['y'].mean().plot(kind='bar', ax=axes[i//4, i%4], color='#FD8185')
    axes[i//4, i%4].set_title(categorial[i])

plt.tight_layout()

# %% [markdown]
# В таком виде, графики уже более интересные. Дак мы видим, для многих признаков, шанс положительного отклика существенно выше.
# Как я уже говорил, я панирую использовать WOE для работы с категориальными признаками.
# Помимо этого, исходя из данных графиков, напрашивается идея сделать более укрупненные категории. Например для образования объединить категории следующим образом:
# 1) 0, 3, 5
# 2) 1, 2
# 3) 6, 7
# 4) 4
# Однако, прелесть WOE в том, что как раз для значений признака, для которых доля положительных откликов сходная, будут близки и значения WOE. Поэтому, из графиков понятно, что применение WOE в данной задаче обосновано и желательно.
#
# Также мы видим, что признаки **housing**, **loan** и **day_of_week** врядли нам чем-то помогут, т.к. судя по графикам, доля положительных откликов от них практически не зависит. *Осторожно, спойлеры.* Далее мы их удалим, но перед этим посмотрим на них с точки зрения Information Value и увидим, что они действительно неинформативны.

# %% [markdown]
# ### Инсайты ###
#
# Пропусков в данных у нас нет, явных выбросов, которые стоило бы вырезать, на мой взгляд тоже нет.
#
# **euribor3m** и **nr.employed** сильно коррелируют с **emp.var.rate**.
# Напомню, **emp.var.rate** - коэффициент изменения занятости - квартальный показатель, **euribor3m** - euribor 3-месячный курс - дневной индикатор, **nr.employed** - количество сотрудников - квартальный показатель. Корреляция изменения занятости и собственно количества занятых вопросов не вызывает, а вот корреляция с Euribor (Euro Interbank Offered Rate, европейская межбанковская ставка предложения) - это интересно. Межбанковская ставка - это один из основных макропараметров экономики государства, т.е. влияет на темпы роста экономики, которые естественным образом влияют на занятость. Логично, но такая сильная корреляция подозрительна :). Слишком быстрый отклик рынка труда.

# %% [markdown]
# ### Выбор метрики ###

# %% [markdown]
# Цель банка состоит в том, чтобы снизить затраты на обзвон всех клиентов, сузив группу обзвона до той группы, для которой наиболее высока вероятность положительного отклика. Для банка важно снизить количество звонков не потеряв при этом клиентов, поэтому наиболее **критичными для банка являются ошибки FalseNegative**, т.к. банк теряет клиентов. Затраты на лишний звонок ниже, чем убыток от потерянного клиента. Исходя из этого, предпочитетльной метрикой будет **Recall**,  которая показывает, какую долю объектов положительного класса из всех объектов положительного класса нашел алгоритм. Однако, **Recall** метрика слишком "однобокая", т.к. стимулирует модель ставить всем объектам метки "1". Поэтому, более предпочтительным я считаю использование **ROC-AUC**, но при этом считаю важным следить отдельно за значением **Recall**. Ниже проиллюстрируем, почему **не стоит использовать Acuracy**

# %% [markdown]
# Что будет, если мы всем объектам поставим метки "0"?

# %%
print ('Accuracy = ', round((1 - df['y'].mean())*100, 1))
print ('Recall = ', round(recall_score(df['y'], [0]*len(df['y'])), 1))
print ('ROC-AUC = ', round(roc_auc_score(df['y'], [0]*len(df['y'])), 1))
# Out:
# Accuracy =  88.7
# Recall =  0.0
# ROC-AUC =  0.5

# %% [markdown]
# Таким образом, мы имеем точность модели 88.7%, однако банк имеет нулевую прибыль, т.к. обзвон потенциальных клиентов не производился.
# Основная причина такой ситуации в том, что целевые классы очень несбалансированны, положительных откликов всего 11.3%,
# поэтому мы предпочтём **ROC-AUC**

# %%
df['y'].value_counts(normalize=True).apply(lambda x: round(x*100, 1))
# Out:
# 0    88.7
# 1    11.3
# Name: y, dtype: float64

# %% [markdown]
# А если мы всем объектам поставим метки "1"?

# %%
print ('Accuracy = ', round((df['y'].mean())*100, 1))
print ('Recall = ', round(recall_score(df['y'], [1]*len(df['y'])), 1))
print ('ROC-AUC = ', round(roc_auc_score(df['y'], [1]*len(df['y'])), 1))
# Out:
# Accuracy =  11.3
# Recall =  1.0
# ROC-AUC =  0.5

# %% [markdown]
# Как мы видим, recall максимальный, но при этом мы обзваниваем всех

# %% [markdown]
# ## Выбор модели

# %% [markdown]
# Как я говорил в начале своей работы, я разделю решение на 2 части:
# **1) "Банковское"**: логистическая регрессия + WOE. Выбор обоснован тем, что Логистическая Регрессия хорошо интерпретируема и используется в реальном банковском моделировании рисков. Однако, Логистическая Регрессия не работает с категориальными признаками, вернее сказать, что работает, но для этого значения категориальных признаков должны быть сравнимы. В том числе для этого вводится понятие WOE (Weight of evidence).
# **2) Свободное от ограничений решение**: в нем я хочу исследовать RandomForest и XGBoost. Делаю ставку на RandomForest, т.к. он устойчив к выбросам (которые я не удалял, т.к. не уверен, что они не важны) и т.к. многие признаки категориальные, значит деревья должны себя показать лучше на таких признаках. Данные модели будут тоже использоваться в сочетании с расчетом WOE (см. конец пункта 4). Также попробую XGBoost на деревьях в соответствии с той же логикой. И в итоге, попробую их объединить.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Удалим признаки **euribor3m** и **nr.employed**, которые сильно коррелируют с **emp.var.rate** (см. пункт 2-3)

# %%
df.drop(['euribor3m', 'nr.employed'], axis=1, inplace=True)

# %% [markdown]
# Удалим признак **duration**, т.к. он показывает продолжительность разговора, необходимость которого мы хотим предсказать

# %%
df.drop(['duration'], axis=1, inplace=True)

# %% [markdown]
# **Посчитаем WOE**:

# %% [markdown]
# ![title](https://user-images.githubusercontent.com/54672403/91747923-bf604c80-ebc7-11ea-9596-e2e6f1e43b74.png)

# %% [markdown]
# Функция расчёта **Information Value**:

# %%
def Information_Value(x, y):
    df = pd.DataFrame({'x': x, 'y': y})
    good = df.groupby('x')['y'].sum() / np.sum(df['y'])
    bad = (df.groupby('x')['y'].count() - df.groupby('x')['y'].sum()) / (len(df['y']) - np.sum(df['y']))
    WOE = np.log((good+0.000001) / bad)
    IV = (good - bad)*WOE
    return IV.sum()

# %% [markdown]
# Функция расчёта **WOE**:

# %%
def WOE(x, y):
    df = pd.DataFrame({'x': x, 'y': y})
    good = df.groupby('x')['y'].sum() / np.sum(df['y'])
    bad = (df.groupby('x')['y'].count() - df.groupby('x')['y'].sum()) / (len(df['y']) - np.sum(df['y']))
    WOE = np.log((good+0.000001)/ bad)
    WOE = pd.Series(WOE).to_dict()
    return x.apply(lambda x: WOE.get(x))

# %% [markdown]
# WOE можно считать для значений признака, однако, учитывая формулу WOE, делать это для вещественных признаков не очень правильно. Лучше разбить диапазон значений на интервалы, закодировать их и посчитать WOE. Отсюда вытекает задача, как оптимально разбить значения признаков на интервалы. Для решения этой задачи, я решил для каждого признака обучать DecisionTreeClassifier и из него получать границы разбиение признака, при которых score максимальный.

# %%
# Функция, которая возвращает границы разбиений
def get_bondaries(x_bondaries, y_bondaries):
    parameters = {'max_depth':[x for x in range(1, 21)], 'min_samples_leaf': [5, 10, 20, 30, 50, 70, 100, 150, 200, 300, 400, 500, 1000, 2000, 5000, 10000, 20000]}
    dtc = DecisionTreeClassifier(random_state=17)
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=17)
    clf = GridSearchCV(dtc, parameters, scoring='roc_auc', cv=skf)
    clf.fit(pd.DataFrame(x_bondaries), y_bondaries)
    print('Best parameters for DT: ', clf.best_params_)
    print('ROC_AUC score: ', round(clf.best_score_, 4))
    tree = clf.best_estimator_
    tree.fit(pd.DataFrame(x_bondaries), y_bondaries)
    print('Boundaries: ', np.sort([x for x in tree.tree_.threshold if x!=-2]))
    return np.sort([x for x in tree.tree_.threshold if x!=-2])

# %% [markdown]
# Расчитываем границы разбиений для каждого признака. Посмотрим параметры дерева, которое делит признаки на интервалы, а так же на само разбиение.

# %%
bondaries = dict()
for col in df.columns:
    if col != 'y':
        print (col)
        bondaries[col] = get_bondaries(df[col], df['y'])
        print ('--------------')
# Out:
# age
# Best parameters for DT:  {'max_depth': 6, 'min_samples_leaf': 300}
# ROC_AUC score:  0.607
# Boundaries:  [22.5 24.5 25.5 26.5 27.5 28.5 29.5 30.5 31.5 34.5 38.5 49.5 55.5 58.5
#  60.5 73.5]
# --------------
# job
# Best parameters for DT:  {'max_depth': 6, 'min_samples_leaf': 5}
# ROC_AUC score:  0.6089
# Boundaries:  [ 0.5  1.5  2.5  3.5  4.5  5.5  6.5  7.5  8.5  9.5 10.5]
# --------------
# marital
# Best parameters for DT:  {'max_depth': 1, 'min_samples_leaf': 5}
# ROC_AUC score:  0.5388
# Boundaries:  [1.5]
# --------------
# education
# Best parameters for DT:  {'max_depth': 3, 'min_samples_leaf': 5}
# ROC_AUC score:  0.5593
# Boundaries:  [0.5 2.5 3.5 5.5 6.5]
# --------------
# default
# Best parameters for DT:  {'max_depth': 1, 'min_samples_leaf': 5}
# ROC_AUC score:  0.5639
# Boundaries:  [0.5]
# --------------
# housing
# Best parameters for DT:  {'max_depth': 1, 'min_samples_leaf': 5}
# ROC_AUC score:  0.5084
# Boundaries:  [1.5]
# --------------
# loan
# Best parameters for DT:  {'max_depth': 1, 'min_samples_leaf': 5}
# ROC_AUC score:  0.5022
# Boundaries:  [0.5]
# --------------
# contact
# Best parameters for DT:  {'max_depth': 1, 'min_samples_leaf': 5}
# ROC_AUC score:  0.6102
# Boundaries:  [0.5]
# --------------
# month
# Best parameters for DT:  {'max_depth': 6, 'min_samples_leaf': 150}
# ROC_AUC score:  0.6553
# Boundaries:  [0.5 1.5 2.5 3.5 4.5 5.5 6.5 7.5 8.5]
# --------------
# day_of_week
# Best parameters for DT:  {'max_depth': 2, 'min_samples_leaf': 5}
# ROC_AUC score:  0.5207
# Boundaries:  [0.5 1.5 2.5]
# --------------
# campaign
# Best parameters for DT:  {'max_depth': 4, 'min_samples_leaf': 200}
# ROC_AUC score:  0.5552
# Boundaries:  [ 1.5  2.5  3.5  4.5  5.5  6.5  7.5 11.5 17.5]
# --------------
# pdays
# Best parameters for DT:  {'max_depth': 7, 'min_samples_leaf': 5}
# ROC_AUC score:  0.5969
# Boundaries:  [5.00e-01 1.50e+00 2.50e+00 3.50e+00 4.50e+00 5.50e+00 6.50e+00 7.50e+00
#  8.50e+00 9.50e+00 1.05e+01 1.15e+01 1.25e+01 1.35e+01 1.45e+01 1.65e+01
#  1.75e+01 2.05e+01 5.13e+02]
# --------------
# previous
# Best parameters for DT:  {'max_depth': 4, 'min_samples_leaf': 10}
# ROC_AUC score:  0.6093
# Boundaries:  [0.5 1.5 2.5 3.5 4.5]
# --------------
# poutcome
# Best parameters for DT:  {'max_depth': 2, 'min_samples_leaf': 5}
# ROC_AUC score:  0.6138
# Boundaries:  [0.5 1.5]
# --------------
# emp.var.rate
# Best parameters for DT:  {'max_depth': 5, 'min_samples_leaf': 10}
# ROC_AUC score:  0.762
# Boundaries:  [-3.20000005 -2.95000005 -2.35000002 -1.75       -1.40000004 -0.65000001
#  -0.15        0.50000001  1.25      ]
# --------------
# cons.price.idx
# Best parameters for DT:  {'max_depth': 9, 'min_samples_leaf': 200}
# ROC_AUC score:  0.784
# Boundaries:  [92.2899971  92.40499878 92.55900192 92.73449707 92.86800003 92.92799759
#  93.01899719 93.13749695 93.28450012 93.40650177 93.5965004  93.83699799
#  93.89699936 93.95600128 94.01050186 94.04100037 94.1269989  94.20699692
#  94.33999634 94.53299713]
# --------------
# cons.conf.idx
# Best parameters for DT:  {'max_depth': 8, 'min_samples_leaf': 200}
# ROC_AUC score:  0.784
# Boundaries:  [-49.75       -48.29999924 -46.64999962 -44.30000114 -42.35000038
#  -41.89999962 -41.29999924 -40.60000038 -40.14999962 -39.89999962
#  -39.04999924 -37.89999962 -36.95000076 -36.25       -35.44999886
#  -34.09999847 -32.19999981 -30.75       -29.94999981 -28.34999943]
# --------------

# %%
# Функция каторая режет признак на интервалы и кодирует их
def splitter(x, col_bondaries):
    for i in range(len(col_bondaries)):
        if i>0:
            if x>col_bondaries[i-1] and x<=col_bondaries[i]:
                return i
        if i==0:
            if x<=col_bondaries[i]:
                return i
        if i==len(col_bondaries)-1:
            if x>col_bondaries[i]:
                return i+1

# %% [markdown]
# Считаем WOE для признаков:

# %%
data_woe = pd.DataFrame()
for col in df.columns:
    if col != 'y' and col!='default' and col!='previous':
        data_woe[col] = df[col].apply(lambda x: splitter(x, bondaries[col]))
        data_woe[col] = WOE(data_woe[col], df['y'])
    if col=='default' or col=='previous':
        data_woe[col] = df[col]

# %% [markdown]
# Посмотрим на **Information Value** категориальных признаков:

# %%
for feature in data_woe.columns:
    print('IV of ', feature, ' = ', Information_Value(data_woe[feature], df['y']), '\n')
# Out:
# IV of  age  =  0.24380189911606037
#
# IV of  job  =  0.18871280550635278
#
# IV of  marital  =  0.02817219672156602
#
# IV of  education  =  0.04810420097260354
#
# IV of  default  =  0.12812942460056045
#
# IV of  housing  =  0.0013818128615726217
#
# IV of  loan  =  0.0002653966141089776
#
# IV of  contact  =  0.2516619082858709
#
# IV of  month  =  0.48511921489207055
#
# IV of  day_of_week  =  0.006481446978382145
#
# IV of  campaign  =  0.07804878898665553
#
# IV of  pdays  =  0.5675163493575648
#
# IV of  previous  =  0.35048518178637994
#
# IV of  poutcome  =  0.5476716036799131
#
# IV of  emp.var.rate  =  1.0697493268709626
#
# IV of  cons.price.idx  =  1.3129341900311586
#
# IV of  cons.conf.idx  =  1.312826760015174

# %% [markdown]
# Сравнивая Information value, видим, что признаки **housing**, **loan** и **day_of_week** являются неинформативными, поэтому мы их можем удалить. Кстати говоря, это же мы видели, когда строили графики, показывающие долю положительных откликов в зависимости от значения признака.

# %%
data_woe.drop(['housing', 'loan', 'day_of_week'], axis=1, inplace=True)

# %% [markdown]
# ## Кросс-валидация и настройка гиперпараметров

# %% [markdown]
# Отложим выборку для теста:

# %%
X_train,  X_test, y_train, y_test = train_test_split(
    data_woe, df['y'], test_size=0.3, stratify=df['y'], random_state=17)

# %% [markdown]
# ##  Логистическая регрессия

# %% [markdown]
# Подберем параметры с помощью **GridSearchCV**:

# %%
parameters = {'penalty':['l1', 'l2'], 'C':[0.12, 0.11, 0.1, 0.09, 0.08, 0.07, 0.06, 0.05, 0.04, 0.03, 0.02, 0.01], 'class_weight':[None, 'balanced']}
LR = LogisticRegression(random_state=17, n_jobs=-1)
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=17)
clf_lr = GridSearchCV(LR, parameters, scoring='roc_auc', cv=skf)
clf_lr.fit(data_woe, df['y'])
print('Best parameters: ', clf_lr.best_params_)
print('ROC_AUC score: ', round(clf_lr.best_score_, 4))

# %% [markdown]
# Теперь посмотрим качество на **отложенной выборке** и заодно оценим время работы **Logit** с наилучшими параметрами:

# %%
start = time.time()
LR_control = LogisticRegression(C=0.04, penalty='l1', solver='liblinear')
# LR_control = LogisticRegression(C=0.04, penalty='l2')
LR_control.fit(X_train, y_train)
print('ROC_AUC on Control data: ', round(roc_auc_score(y_test, LR_control.predict_proba(df_test)[:,1]), 4))
print('Overall time: ', round(time.time()-start, 1))
# Out:
# ROC_AUC on Control data:  0.7951
# Overall time:  1.0

# %% [markdown]
# ## Случайный лес

# %%
parameters = {'n_estimators':[280, 290, 300, 310, 320, 330], 'max_depth':[8, 9, 10, 11, 12, 15], 'min_samples_leaf': [1, 10, 30, 50, 100]}
RFC = RandomForestClassifier(random_state=17, n_jobs=-1)
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=17)
clf_rfc = GridSearchCV(RFC, parameters, scoring='roc_auc', cv=skf)
clf_rfc.fit(data_woe, df['y'])
print('Best parameters: ', clf_rfc.best_params_)
print('ROC_AUC score: ', round(clf_rfc.best_score_, 4))

# %% [markdown]
# Результат на **отложенной выборке** с наилучшими параметрами:

# %%
start = time.time()
RF_control = RandomForestClassifier(max_depth=9, n_estimators=290)
RF_control.fit(X_train, y_train)
print('ROC_AUC on Control data: ', round(roc_auc_score(y_test, RF_control.predict_proba(df_test)[:,1]), 4))
print("Overall time:", round(time.time()-start, 1))
# Out:
# ROC_AUC on Control data:  0.7989
# Overall time: 2.6

# %% [markdown]
# Как мы видим, на отложенной выборке себя показывает **RandomForest** с **максимальной глубиной = 9** и **Количеством деревьев = 290**. Для сравнения, посмотрим результат работы **XGBoost**:

# %% [markdown]
# ## XGBoost

# %%
parameters = {'n_estimators':[40, 50, 60, 100, 200, 300], 'max_depth':[2, 3, 4, 5, 6]}
xgb = XGBClassifier(random_state=17, n_jobs=-1)
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=17)
clf = GridSearchCV(xgb, parameters, scoring='roc_auc', cv=skf)
clf.fit(data_woe, df['y'])
print('Best parameters: ', clf.best_params_)
print('ROC_AUC score: ', round(clf.best_score_, 4))

# %%
start = time.time()
xgb_control = XGBClassifier(max_depth=4, n_estimators=60, random_state=17, n_jobs=-1)
xgb_control.fit(X_train, y_train)
print('ROC_AUC on Control data: ', round(roc_auc_score(y_test, xgb_control.predict_proba(df_test)[:,1]), 4))
print("Overall time:", round(time.time()-start, 1))
# Out:
# ROC_AUC on Control data:  0.7981
# Overall time: 0.8

# %% [markdown]
# Как видим, все три алгоритма показали близкие результаты. **XGBoost** и **Random Forest** чуть впереди, но **Логит** показал достойные результаты.

# %% [markdown]
# ## Создание новых признаков

# %% [markdown]
# В случае данного датасета, большинство признаков, которые логично создать, не имеет смысла вводить в модель, т.к. зависимости, которые они иллюстрируют должны хорошо выделяться случайным лесом и без создания новых признаков. Однако, есть признак, который хочется добавить в модель. У нас есть признак **pdays** (количество дней, прошедшее с предыдущего контакта) и **previous** (количество контактов с данным клиенто до текущей компании). В данном случае, количество контактов с клиентом разделим на количество дней с последнего контакта. Логика в том, что чем больше времени прошло, тем менее важно, как часто ранее общались с клиентом. Назовем это признак **previous_with_memory**.

# %%
def previous_with_memory(x):
    if x[0] == 0: return 0
    else: return x[1]/x[0]

# %%
data_new = data_woe.copy()
data_new['previous_with_memory'] = raw_data[['pdays', 'previous']].apply(previous_with_memory, axis=1)

# %%
X_train_memory, X_test_memory, y_train_memory, y_test_memory = \
    train_test_split(data_new, df['y'], test_size=0.3, stratify=df['y'], random_state=17)

# %%
start = time.time()
RF_control = RandomForestClassifier(max_depth=9, n_estimators=290, random_state=17, n_jobs=-1)
RF_control.fit(X_train_memory, y_train_memory)
print('ROC_AUC on Control data: ', round(roc_auc_score(y_test_memory, RF_control.predict_proba(X_test_memory)[:,1]), 4))
print("Overall time:", round(time.time()-start, 1))
# Out:
# ROC_AUC on Control data:  0.7982
# Overall time: 0.6

# %% [markdown]
# Для сравнения, запустим **XGBoost** на новых признаках:

# %%
start = time.time()
xgb_control = XGBClassifier(max_depth=4, n_estimators=60, random_state=17, n_jobs=-1)
xgb_control.fit(X_train_memory, y_train_memory)
print('ROC_AUC on Control data: ', round(roc_auc_score(y_test_memory, RF_control.predict_proba(X_test_memory)[:,1]), 4))
print("Overall time:", round(time.time()-start, 1))
# Out:
# ROC_AUC on Control data:  0.7982
# Overall time: 0.2

# %% [markdown]
# Как мы видим, прироста мы не увидели, поэтому не будем его использовать. Помимо данного признака, вариантов для создания признаков я не вижу.

# %% [markdown]
# ##  Ансамбль
# Попробуем объединить алгоритмы **Random Forest** и **XGBoost** в ансамбль

# %%
from sklearn.ensemble import VotingClassifier
clf1 = LogisticRegression(C=0.04, penalty='l1', random_state=17, n_jobs=-1)
clf2 = RandomForestClassifier(max_depth=9, n_estimators=290, random_state=17, n_jobs=-1)
clf3 = XGBClassifier(max_depth=4, n_estimators=60, random_state=17, n_jobs=-1)

eclf = VotingClassifier(estimators=[('lr', clf1), ('rf', clf2), ('xgb', clf3)], voting='soft')
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=17)

for clf, label in zip([clf2, clf3, eclf], ['Random Forest', 'XGBoost', 'Ensemble']):
    scores = cross_val_score(clf, data_woe, df['y'], cv=skf, scoring='roc_auc', n_jobs=-1)
    print("ROC-AUC: %0.4f (+/- %0.4f) [%s]" % (scores.mean(), scores.std(), label))
# Out:
# ROC-AUC: 0.7978 (+/- 0.0069) [Random Forest]
# ROC-AUC: 0.7988 (+/- 0.0069) [XGBoost]
# ROC-AUC: 0.7984 (+/- 0.0067) [Ensemble]

# %% [markdown]
# Объединение не дало прирост качества и незначительно увеличило устойчивость алгоритма.

# %% [markdown]
# ## Кривые валидации и обучения
# Кривые буду строить для **Random Forest**, т.к. сделал на него основную ставку. В целом он незначительно уступил XGBoost

# %%
plt.figure(figsize=(8, 8))
param_range = [2, 5, 10, 50, 100, 150, 200, 250, 300, 350, 400]
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=17)
train_scores, test_scores = validation_curve(
    RandomForestClassifier(max_depth=9, random_state=17), data_woe, df['y'], param_name='n_estimators', param_range=param_range,
    cv=skf, scoring="roc_auc", n_jobs=-1)

train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)


plt.figure(figsize=(10,5))
plt.title("Validation Curve with Random Forest")
plt.xlabel("n_estimators")
plt.ylabel("Score")
plt.ylim(0.77, 0.84)
lw = 2
plt.semilogx(param_range, train_scores_mean, label="Training score",
             color="darkorange", lw=lw)
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2,
                 color="darkorange", lw=lw)
plt.semilogx(param_range, test_scores_mean, label="Cross-validation score",
             color="navy", lw=lw)
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2,
                 color="navy", lw=lw)
plt.legend(loc="best")
plt.grid(color='grey', linestyle='-', linewidth=0.2)
plt.show()

# %%
plt.figure(figsize=(8, 8))
param_range = [2, 5, 10, 50, 100, 150, 200, 250, 300, 350, 400]
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=17)
train_scores, test_scores = validation_curve(
    RandomForestClassifier(max_depth=9, random_state=17), data_woe, df['y'], param_name='n_estimators', param_range=param_range,
    cv=skf, scoring="roc_auc", n_jobs=-1)

train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.figure(figsize=(10,5))
plt.title("Validation Curve with Random Forest")
plt.xlabel("n_estimators")
plt.ylabel("Score")
plt.ylim(0.77, 0.84)
lw = 2
plt.semilogx(param_range, train_scores_mean, label="Training score",
             color="darkorange", lw=lw)
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2,
                 color="darkorange", lw=lw)
plt.semilogx(param_range, test_scores_mean, label="Cross-validation score",
             color="navy", lw=lw)
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2,
                 color="navy", lw=lw)
plt.legend(loc="best")
plt.grid(color='grey', linestyle='-', linewidth=0.2)
plt.show()

# %%
from sklearn.model_selection import learning_curve
plt.figure(figsize=(8, 6))

plt.title('Learning Curves for Random Forest')
plt.xlabel("Training examples")
plt.ylabel("Score")
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=17)
train_sizes, train_scores, test_scores = learning_curve(RandomForestClassifier(max_depth=9, n_estimators=290, random_state=17), data_woe, df['y'], cv=skf, n_jobs=1, train_sizes=np.linspace(.1, 1.0, 10), scoring='roc_auc')
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)


plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# Судя по кривой обучения, в целом, данных достаточно, но, видимо, некоторую прибавку качества за счёт увеличения датасета всё же можно было получить.
# Из кривой валидации видно, что основной рост качества происходит до 100 деревьев, далее качество меняется незначительно как в плюс так и в минус.

# %% [markdown]
# ## Итог

# %% [markdown]
# Алгоритмы основанные на ансамблях деревьев показали себя очень хорошо, что не удивительно, учитывая, что мы считали WOE (т.е. создали разбиения, получив категориальные признаки для которых на значениях задана операция сравнения), данные не разреженные, размер датасета не маленький.
# При этом логистическая регрессия хоть и уступает, но показывает себя достаточно неплохо, т.е. при серьезной работе с ней, можно получать неплохие результаты, при этом интерпретируемые, что является большим плюсом для некоторых бизнес-задач.
